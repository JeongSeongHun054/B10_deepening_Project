# %%
import sklearn
import numpy as numpy
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# C:\Users\yjs63\AppData\Local\Temp\ipykernel_22764\2028690188.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('C:/Users/yjs63/OneDrive/바탕 화면/스파르타코딩/머신러닝(주피터노트북)/train.csv')

# %%
Brocoly_data = df[df['item'] == 'BC']
Brocoly_data
# Out:
#                     ID   timestamp item corporation location  supply(kg)  \
# 42644  BC_A_J_20190101  2019-01-01   BC           A        J         0.0
# 42645  BC_A_J_20190102  2019-01-02   BC           A        J         0.0
# 42646  BC_A_J_20190103  2019-01-03   BC           A        J      7616.0
# 42647  BC_A_J_20190104  2019-01-04   BC           A        J      7488.0
# 42648  BC_A_J_20190105  2019-01-05   BC           A        J     10408.0
# ...                ...         ...  ...         ...      ...         ...
# 56346  BC_E_S_20230227  2023-02-27   BC           E        S      2200.0
# 56347  BC_E_S_20230228  2023-02-28   BC           E        S      1024.0
# 56348  BC_E_S_20230301  2023-03-01   BC           E        S      2160.0
# 56349  BC_E_S_20230302  2023-03-02   BC           E        S      1152.0
# 56350  BC_E_S_20230303  2023-03-03   BC           E        S      1336.0
#
#        price(원/kg)
# 42644          0.0
# 42645          0.0
# 42646       2559.0
# ...

# %%
#Brocoly_data.plot()
#plt.show()
sns.scatterplot( data = Brocoly_data, x = 'supply(kg)' , y = 'price(원/kg)')
sns.lineplot( data = Brocoly_data, x = 'supply(kg)' , y = 'price(원/kg)')
#plt.figure(figsize=(40,20))
# Out:
# <Axes: xlabel='supply(kg)', ylabel='price(원/kg)'>
# C:\Users\yjs63\AppData\Roaming\Python\Python39\site-packages\IPython\core\events.py:82: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\yjs63\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.set(rc={"figure.figsize":(80, 10)}) #width=3, #height=4
sns.scatterplot( data = Brocoly_data, x = 'supply(kg)' , y = 'price(원/kg)')
sns.lineplot( data = Brocoly_data, x = 'supply(kg)' , y = 'price(원/kg)')
sns.regplot( data = Brocoly_data, x = 'supply(kg)' , y = 'price(원/kg)')
sns.lmplot( data = Brocoly_data, x = 'supply(kg)' , y = 'price(원/kg)')
# Out:
# c:\Python\Python39\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yjs63\AppData\Roaming\Python\Python39\site-packages\IPython\core\events.py:82: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\yjs63\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.set(rc={"figure.figsize":(80, 10)}) #width=3, #height=4
sns.scatterplot( data = Brocoly_data, x = 'price(원/kg)' , y = 'supply(kg)')
sns.lineplot( data = Brocoly_data, x = 'price(원/kg)' , y = 'supply(kg)')
# Out:
# <Axes: xlabel='price(원/kg)', ylabel='supply(kg)'>
# C:\Users\yjs63\AppData\Roaming\Python\Python39\site-packages\IPython\core\events.py:82: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\yjs63\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
sns.lmplot( data = Brocoly_data, x = 'supply(kg)' , y = 'price(원/kg)')
# Out:
# c:\Python\Python39\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\yjs63\AppData\Roaming\Python\Python39\site-packages\IPython\core\events.py:82: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\yjs63\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
from sklearn.linear_model import LinearRegression
model_lr = LinearRegression()
type(model_lr)
# Out:
# sklearn.linear_model._base.LinearRegression

# %%
b
